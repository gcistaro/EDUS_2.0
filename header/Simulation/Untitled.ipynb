# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.loadtxt("MasterR.txt", unpack=True)
y = np.loadtxt("R.txt", unpack=True)

fig,ax=plt.subplots()
plt.scatter(x[0],x[1], s=20)
plt.scatter(y[0],y[1], s=40)
circle = plt.Circle((0,0),radius=20, fill=False, ls='--')
ax.add_patch(circle)
#ax.set_xlim(-25,25)
#ax.set_ylim(-25,25)
ax.set_aspect('equal')
